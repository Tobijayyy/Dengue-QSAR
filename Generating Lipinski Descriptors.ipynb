# %%
from rdkit import Chem
from rdkit.Chem import Lipinski, Descriptors

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('preprocessed_dengue_bioactivity_df.csv')

# %%
df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1232      CHEMBL5190612  Cc1ccc(S(=O)(=O)Nc2ccc(-c3nnc(SCc4ccc(C(F)(F)F...
# 1233      CHEMBL5176952  Cc1ccc(S(=O)(=O)Nc2ccc(-c3nnc(SCc4cccc(C(F)(F)...
# 1234      CHEMBL5184942  Cc1ccc(S(=O)(=O)Nc2ccc(-c3nnc(SCc4ccccc4C(F)(F...
# 1235      CHEMBL4526128  O=C(N[C@@H](Cc1ccc(O)cc1)C(=O)O)c1cc(-c2ccccc2...
# 1236      CHEMBL5177478  CC(=O)N[C@@H](CCCCN)C(=O)N[C@@H](CCCCN)C(=O)N[...
#
#       standard_value  bio_activity
# 0           100000.0      inactive
# 1            12310.0      inactive
# 2           100000.0      inactive
# 3            50970.0      inactive
# 4           100000.0      inactive
# ...              ...           ...
# 1232         25200.0      inactive
# 1233         23900.0      inactive
# 1234         24000.0      inactive
# 1235          9610.0  intermediate
# 1236           200.0        active
#
# [1237 rows x 4 columns]

# %%
# Inspired by DataProfessor
def lipinski(smiles, verbose=False):

    moldata = []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df_lipinski = lipinski(df.canonical_smiles)

# %%
df_lipinski
# Out:
#            MW     LogP  NumHDonors  NumHAcceptors
# 0     240.262  2.80020         0.0            4.0
# 1     268.224  2.44040         1.0            4.0
# 2     407.426  1.38560         1.0            5.0
# 3     306.277  3.84800         1.0            5.0
# 4     372.772  2.36698         0.0            8.0
# ...       ...      ...         ...            ...
# 1232  505.543  6.15692         1.0            6.0
# 1233  505.543  6.15692         1.0            6.0
# 1234  505.543  6.15692         1.0            6.0
# 1235  582.678  6.02400         3.0            7.0
# 1236  712.814  4.00560         6.0            7.0
#
# [1237 rows x 4 columns]

# %%
df_combined = pd.concat([df, df_lipinski], axis=1)

# %% [markdown]
# ### Converting the standard values into pIC50 values

# %%
df_combined.standard_value.max()
# Out:
# 432000.0

# %%
def pIC50(df):
    pIC50 = []

    for i in df['standard_value']:
        molar = i*(10**-9) # From nM to M
        pIC50.append(-np.log10(molar))

    df['pIC50'] = pIC50
    x = df.drop('standard_value', axis=1)
        
    return x

# %%
pIC50(df_combined).pIC50.min()
# Out:
# 3.364516253185088

# %%
df_combined
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL1401841                         COc1ccc2nc3cccc(OC)c3nc2c1
# 1         CHEMBL1608853           O=C(O)c1ccc2c(c1)C(=O)/C(=C\c1ccco1)C2=O
# 2         CHEMBL1429799  O=C1NN(c2ccccc2)C(=O)/C1=C\c1ccccc1OCC(=O)N1CC...
# 3          CHEMBL246446           O=C(O)c1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 4         CHEMBL1383455  CCn1nc([N+](=O)[O-])c(C(C#N)c2nc3ccccc3n2C)c(C...
# ...                 ...                                                ...
# 1232      CHEMBL5190612  Cc1ccc(S(=O)(=O)Nc2ccc(-c3nnc(SCc4ccc(C(F)(F)F...
# 1233      CHEMBL5176952  Cc1ccc(S(=O)(=O)Nc2ccc(-c3nnc(SCc4cccc(C(F)(F)...
# 1234      CHEMBL5184942  Cc1ccc(S(=O)(=O)Nc2ccc(-c3nnc(SCc4ccccc4C(F)(F...
# 1235      CHEMBL4526128  O=C(N[C@@H](Cc1ccc(O)cc1)C(=O)O)c1cc(-c2ccccc2...
# 1236      CHEMBL5177478  CC(=O)N[C@@H](CCCCN)C(=O)N[C@@H](CCCCN)C(=O)N[...
#
#       standard_value  bio_activity       MW     LogP  NumHDonors  \
# 0           100000.0      inactive  240.262  2.80020         0.0
# 1            12310.0      inactive  268.224  2.44040         1.0
# 2           100000.0      inactive  407.426  1.38560         1.0
# 3            50970.0      inactive  306.277  3.84800         1.0
# 4           100000.0      inactive  372.772  2.36698         0.0
# ...              ...           ...      ...      ...         ...
# 1232         25200.0      inactive  505.543  6.15692         1.0
# 1233         23900.0      inactive  505.543  6.15692         1.0
# 1234         24000.0      inactive  505.543  6.15692         1.0
# 1235          9610.0  intermediate  582.678  6.02400         3.0
# 1236           200.0        active  712.814  4.00560         6.0
#
#       NumHAcceptors     pIC50
# 0               4.0  4.000000
# 1               4.0  4.909742
# 2               5.0  4.000000
# 3               5.0  4.292685
# 4               8.0  4.000000
# ...             ...       ...
# 1232            6.0  4.598599
# 1233            6.0  4.621602
# 1234            6.0  4.619789
# 1235            7.0  5.017277
# 1236            7.0  6.698970
#
# [1237 rows x 9 columns]

# %%
df_combined.to_csv('df_combined.csv', index=False)
